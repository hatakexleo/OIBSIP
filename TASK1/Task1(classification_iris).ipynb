# %%
#task1.
#classification of species according to attributes in iris dataset.
#building a model that can classify and give the output as to what species that a given value of attributes will belong to.



import pandas as pd  #importing pandas to get the data imported for csv(coma separated values) ifle.


import seaborn as sns  #seaborn and matplotlib for visualization.
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Iris.csv') #getting the dataset imported, which will be converted into dataframe

# %%
df  #printing the dataframe , by observing ,we have 6 columns , 150 rows , species name and its proterties like sep_len etc.
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.drop(['Id'],axis=1,inplace=True) #we don't need id in any of our requirements so dropping it
l=df.Species
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
col=['sepal_len','sepal_wid','petal_len','petal_wid','species'] #renaming column names for ease of operations
df.columns=col

# %%
df
# Out:
#      sepal_len  sepal_wid  petal_len  petal_wid         species
# 0          5.1        3.5        1.4        0.2     Iris-setosa
# 1          4.9        3.0        1.4        0.2     Iris-setosa
# 2          4.7        3.2        1.3        0.2     Iris-setosa
# 3          4.6        3.1        1.5        0.2     Iris-setosa
# 4          5.0        3.6        1.4        0.2     Iris-setosa
# ..         ...        ...        ...        ...             ...
# 145        6.7        3.0        5.2        2.3  Iris-virginica
# 146        6.3        2.5        5.0        1.9  Iris-virginica
# 147        6.5        3.0        5.2        2.0  Iris-virginica
# 148        6.2        3.4        5.4        2.3  Iris-virginica
# 149        5.9        3.0        5.1        1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.info() #getting info of attributes datatype , here we go all the attributes in numerical except 1 categorical variable
#that is species we can convert it to numerical data with help of labelencoder in sklearn.preprocessing.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sepal_len  150 non-null    float64
#  1   sepal_wid  150 non-null    float64
#  2   petal_len  150 non-null    float64
#  3   petal_wid  150 non-null    float64
#  4   species    150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['species'].unique() #this gives the details of how many uniques values were present in column species
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
#species values will be replaced with the index of its above array
#0-> Iris-setosa  1->Iris-versicolor 2->dtype=object

# %%
df.species=enc.fit_transform(df.species) #this do the work of converting object/stirng type values to integers for us.

# %%
df
# Out:
#      sepal_len  sepal_wid  petal_len  petal_wid  species
# 0          5.1        3.5        1.4        0.2        0
# 1          4.9        3.0        1.4        0.2        0
# 2          4.7        3.2        1.3        0.2        0
# 3          4.6        3.1        1.5        0.2        0
# 4          5.0        3.6        1.4        0.2        0
# ..         ...        ...        ...        ...      ...
# 145        6.7        3.0        5.2        2.3        2
# 146        6.3        2.5        5.0        1.9        2
# 147        6.5        3.0        5.2        2.0        2
# 148        6.2        3.4        5.4        2.3        2
# 149        5.9        3.0        5.1        1.8        2
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sepal_len  150 non-null    float64
#  1   sepal_wid  150 non-null    float64
#  2   petal_len  150 non-null    float64
#  3   petal_wid  150 non-null    float64
#  4   species    150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline

plt.xlabel('attributes')
plt.ylabel('species')
plt.plot(df.sepal_len,df.species,'*',color='green',alpha=.5,label='sep_len')
plt.plot(df.sepal_wid,df.species,'*',color='blue',alpha=.5,label='sep_wid')
plt.plot(df.petal_len,df.species,'*',color='grey',alpha=.5,label='pet_len')
plt.plot(df.petal_wid,df.species,'*',color='yellow',alpha=.5,label='pet_wid')
plt.axvline(x=df.sepal_len.min())
plt.axvline(x=df.sepal_len.max())
plt.axvline(x=df.sepal_wid.min(),color='blue')
plt.axvline(x=df.sepal_wid.max(),color='blue')
plt.axvline(x=df.petal_len.min(),color='grey')
plt.axvline(x=df.petal_len.max(),color='grey')
plt.axvline(x=df.petal_wid.min(),color='yellow')
plt.axvline(x=df.petal_wid.max(),color='yellow')
plt.title('Atrributes vs species')
plt.legend()
plt.show()

# %%
plt.plot(df.sepal_len,df.species,'*',color='green',alpha=.5)
plt.axvline(x=df.sepal_len.min(),color='green')
plt.axvline(x=df.sepal_len.max(),color='green')

# %%
plt.plot(df.sepal_wid,df.species,'*',color='blue',alpha=.5)
plt.axvline(x=df.sepal_wid.min(),color='blue')
plt.axvline(x=df.sepal_wid.max(),color='blue')

# %%
plt.plot(df.petal_len,df.species,'*',color='grey',alpha=.5)
plt.axvline(x=df.petal_len.min(),color='grey')
plt.axvline(x=df.petal_len.max(),color='grey')

# %%
plt.plot(df.petal_wid,df.species,'*',color='yellow',alpha=.5)
plt.axvline(x=df.petal_wid.min(),color='yellow')
plt.axvline(x=df.petal_wid.max(),color='yellow')

# %%
# import seaborn as sns
sns.pairplot(df,hue="species")

# %%
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
model1=LinearRegression()
model2=LogisticRegression(max_iter=1000)
model3=KNeighborsClassifier()

# x=df[['sepal_len','sepal_wid','petal_len','petal_wid']]
# y=df.species

# %%
#we split the data using train_test_split into 2 parts one for training the model and other for testing it's accuracy.

from sklearn.model_selection import train_test_split as t
x,X,y,Y=t(df[['sepal_len','sepal_wid','petal_len','petal_wid']],df.species,test_size=.05)

# %%
model1.fit(x,y);model2.fit(x,y);model3.fit(x,y)
# Out:
# KNeighborsClassifier()

# %%
p1=model1.predict(X)
p2=model2.predict(X)
p3=model3.predict(X)

# %%
from sklearn import metrics as m

# %%
m.r2_score(Y,p1)
# Out:
# 0.9069525221921153

# %%
m.accuracy_score(Y,p2)
# Out:
# 1.0

# %%
m.accuracy_score(Y,p3)
# Out:
# 1.0

# %%
# k-fold cros-validation is another apporoch for model evaluaton with repeated train/test splits of complete data.
x=df[['sepal_len','sepal_wid','petal_len','petal_wid']]
y=df.species
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model3,x,y,scoring='accuracy',cv=5)
print(scores)
print(str('%.2f' % (scores.mean()*100)+'%'))
# Out:
# [0.96666667 1.         0.93333333 0.96666667 1.        ]
# 97.33%

# %%
#with a accuracy of 97.33 the model will be able to classify data species following k-nearest-neighbours model.
